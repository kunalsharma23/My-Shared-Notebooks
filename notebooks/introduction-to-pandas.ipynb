# %% [markdown]
# # This is an example of pandas

# %%
import pandas as pd

# %%
all_india=pd.read_csv('Data/Salaries.csv')

# %%
# two tyes of data types in pandas
#1. series
#2. dataframe

# %%
series=pd.Series(['BMW','AUDI','HONDA','HYUNDAI'])

# %%
series
# Out:
# 0        BMW
# 1       AUDI
# 2      HONDA
# 3    HYUNDAI
# dtype: object

# %%
color=pd.Series(['red','yellow','green','white'])

# %%
color
# Out:
# 0       red
# 1    yellow
# 2     green
# 3     white
# dtype: object

# %%
car_data=pd.DataFrame({'car make': series,'colors':color})

# %%
car_data
# Out:
#   car make  colors
# 0      BMW     red
# 1     AUDI  yellow
# 2    HONDA   green
# 3  HYUNDAI   white

# %%
all_india=pd.read_csv('Data/all_india.csv')

# %%
all_india.
# Out:
#                   officename  pincode officeType Deliverystatus divisionname  \
# 0              Achalapur B.O   504273        B.O       Delivery     Adilabad
# 1                    Ada B.O   504293        B.O       Delivery     Adilabad
# 2                Adegaon B.O   504307        B.O       Delivery     Adilabad
# 3  Adilabad Collectorate S.O   504001        S.O   Non-Delivery     Adilabad
# 4               Adilabad H.O   504001        H.O       Delivery     Adilabad
#
#   regionname      circlename     Taluk Districtname  statename     Telephone  \
# 0  Hyderabad  Andhra Pradesh  Asifabad     Adilabad  TELANGANA           NaN
# 1  Hyderabad  Andhra Pradesh  Asifabad     Adilabad  TELANGANA           NaN
# 2  Hyderabad  Andhra Pradesh     Boath     Adilabad  TELANGANA           NaN
# 3  Hyderabad  Andhra Pradesh  Adilabad     Adilabad  TELANGANA  08732-226703
# 4  Hyderabad  Andhra Pradesh  Adilabad     Adilabad  TELANGANA  08732-226738
#
# ...

# %%
car_sales.to_csv('exported-car-sales.csv',index=False)

# %%
expcarsale=pd.read_csv('exported-car-sales.csv')

# %%
expcarsale.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe Data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_col=car_sales.columns

# %%
car_col
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing the data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# # test for loc and iloc by creating a animal series

# %%
animals=pd.Series(['bird','lion','cat','dog','ox'], index=[1,3,5,9,3])
animals
# Out:
# 1    bird
# 3    lion
# 5     cat
# 9     dog
# 3      ox
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'dog'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.iloc[5]
# Out:
# Make                Toyota
# Colour               Green
# Odometer (KM)        99213
# Doors                    4
# Price            $4,500.00
# Name: 5, dtype: object

# %%
animals.iloc[:4]
# Out:
# 1    bird
# 3    lion
# 5     cat
# 9     dog
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales['Colour']=='Blue']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00

# %%
car_sales[car_sales['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %% [markdown]
# ## To view data in two columns

# %%
pd.crosstab(car_sales['Make'],car_sales['Colour'])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.to_csv('exp-car-sales.jpeg',index=False)

# %%
exp=pd.read_csv('exp-car-sales.jpeg')

# %%
exp
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
car_sales['Odometer (KM)'].plot()

# %%
car_sales['Doors'].plot()

# %%
car_sales['Price'].dtype
# Out:
# dtype('O')

# %%
car_sales['Odometer (KM)'].hist()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Price'].plot()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
car_sales['Price'].plot()

# %% [markdown]
# ## Manipulating data 1

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Make'] = car_sales['Make'].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   400000
# 1   HONDA    Red          87899      4   500000
# 2  TOYOTA   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  NISSAN  White         213095      4   350000
# 5  TOYOTA  Green          99213      4   450000
# 6   HONDA   Blue          45698      4   750000
# 7   HONDA   Blue          54738      4   700000
# 8  TOYOTA  White          60000      4   625000
# 9  NISSAN  White          31600      4   970000

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   400000
# 1   HONDA    Red          87899      4   500000
# 2  TOYOTA   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  NISSAN  White         213095      4   350000
# 5  TOYOTA  Green          99213      4   450000
# 6   HONDA   Blue          45698      4   750000
# 7   HONDA   Blue          54738      4   700000
# 8  TOYOTA  White          60000      4   625000
# 9  NISSAN  White          31600      4   970000

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   400000
# 1   HONDA    Red          87899      4   500000
# 2  TOYOTA   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  NISSAN  White         213095      4   350000

# %%
car_sales_missing=pd.read_csv('car-sales-missing.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing=pd.read_csv('car-sales-missing.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer']=car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing['Price']=car_sales_misisng['Price'].str.replace('[$\,\.]','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-165-4438c8190780> in <module>
# ----> 1 car_sales_missing['Price']=car_sales_misisng['Price'].str.replace('[$\,\.]','').astype(int)
#
# NameError: name 'car_sales_misisng' is not defined

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing['Price']=car_sales_misisng['Price'].str.replace('[$\,\.]','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-4438c8190780> in <module>
# ----> 1 car_sales_missing['Price']=car_sales_misisng['Price'].str.replace('[$\,\.]','').astype(int)
#
# NameError: name 'car_sales_misisng' is not defined

# %%
car_sales_missing=pd.read_csv('car-sales-missing.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing=pd.read_csv('car-sales-missing.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
#car_sales_missing['Odometer']=car_sales_misisng['Odometer'].fillna(car_sales_missing['Odometer'].mean())
car_sales_missing['Odometer']=car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing=pd.read_csv('car-sales-missing.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer']=car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.mean()
# Out:
# Odometer    92302.666667
# Doors           4.000000
# dtype: float64

# %%
car_sales_missing_dropped=car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing['Price']=car_sales_misisng['Price'].str.replace('[\$\,\.]','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-196-1caa22b3f1ed> in <module>
# ----> 1 car_sales_missing['Price']=car_sales_misisng['Price'].str.replace('[\$\,\.]','').astype(int)
#
# NameError: name 'car_sales_misisng' is not defined

# %%
car_sales_missing["Price"] = car_sales_missing["Price"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-f8ccaa844e02> in <module>
# ----> 1 car_sales_missing["Price"] = car_sales_missing["Price"].str.replace('[\$\,\.]', '').astype(int)
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\Desktop\sample_project\env\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   400000
# 1   HONDA    Red          87899      4   500000
# 2  TOYOTA   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  NISSAN  White         213095      4   350000
# 5  TOYOTA  Green          99213      4   450000
# 6   HONDA   Blue          45698      4   750000
# 7   HONDA   Blue          54738      4   700000
# 8  TOYOTA  White          60000      4   625000
# 9  NISSAN  White          31600      4   970000

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped['Price']=car_sales_missing_dropped['Price'].str.replace('[\$\,\.]','').astype(int)
# Out:
# C:\Users\kunal.sharma2395\Desktop\sample_project\env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
car_sales=pd.read_csv('car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price']=car_sales['Price'].str.replace('[\$\,\.]','').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# # Data Manipulation
#
# # Create column form Series

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Price'].plot()

# %%
car_sales['Price']=car_sales['Price']/100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# series to get number of seats
seats=pd.Series([5,5,5,5,5,5])

# %%
car_sales['Seats']=seats

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales['Price'].plot()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales.fillna(5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales.fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
engine_size=[5,3,9,54,2,5,5,1,2,9]
car_sales['engine size (L)']=engine_size

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)
# 0  Toyota  White         150043      4   4000.0    5.0                5
# 1   Honda    Red          87899      4   5000.0    5.0                3
# 2  Toyota   Blue          32549      3   7000.0    5.0                9
# 3     BMW  Black          11179      5  22000.0    5.0               54
# 4  Nissan  White         213095      4   3500.0    5.0                2
# 5  Toyota  Green          99213      4   4500.0    5.0                5
# 6   Honda   Blue          45698      4   7500.0    5.0                5
# 7   Honda   Blue          54738      4   7000.0    5.0                1
# 8  Toyota  White          60000      4   6250.0    5.0                2
# 9  Nissan  White          31600      4   9700.0    5.0                9

# %%
car_sales['Price/Doors']=car_sales['Price'] / car_sales['Doors']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 0  Toyota  White         150043      4   4000.0    5.0                5
# 1   Honda    Red          87899      4   5000.0    5.0                3
# 2  Toyota   Blue          32549      3   7000.0    5.0                9
# 3     BMW  Black          11179      5  22000.0    5.0               54
# 4  Nissan  White         213095      4   3500.0    5.0                2
# 5  Toyota  Green          99213      4   4500.0    5.0                5
# 6   Honda   Blue          45698      4   7500.0    5.0                5
# 7   Honda   Blue          54738      4   7000.0    5.0                1
# 8  Toyota  White          60000      4   6250.0    5.0                2
# 9  Nissan  White          31600      4   9700.0    5.0                9
#
#    KM/engine size  Price/Doors
# 0     1000.000000  1000.000000
# 1     1250.000000  1250.000000
# 2     2333.333333  2333.333333
# 3     4400.000000  4400.000000
# ...

# %%
car_sales['Wheels']=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 0  Toyota  White         150043      4   4000.0    5.0                5
# 1   Honda    Red          87899      4   5000.0    5.0                3
# 2  Toyota   Blue          32549      3   7000.0    5.0                9
# 3     BMW  Black          11179      5  22000.0    5.0               54
# 4  Nissan  White         213095      4   3500.0    5.0                2
# 5  Toyota  Green          99213      4   4500.0    5.0                5
# 6   Honda   Blue          45698      4   7500.0    5.0                5
# 7   Honda   Blue          54738      4   7000.0    5.0                1
# 8  Toyota  White          60000      4   6250.0    5.0                2
# 9  Nissan  White          31600      4   9700.0    5.0                9
#
#    KM/engine size  Price/Doors  Wheels
# 0     1000.000000  1000.000000       4
# 1     1250.000000  1250.000000       4
# 2     2333.333333  2333.333333       4
# ...

# %%
car_sales['Pass road safety']=True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 0  Toyota  White         150043      4   4000.0    5.0                5
# 1   Honda    Red          87899      4   5000.0    5.0                3
# 2  Toyota   Blue          32549      3   7000.0    5.0                9
# 3     BMW  Black          11179      5  22000.0    5.0               54
# 4  Nissan  White         213095      4   3500.0    5.0                2
# 5  Toyota  Green          99213      4   4500.0    5.0                5
# 6   Honda   Blue          45698      4   7500.0    5.0                5
# 7   Honda   Blue          54738      4   7000.0    5.0                1
# 8  Toyota  White          60000      4   6250.0    5.0                2
# 9  Nissan  White          31600      4   9700.0    5.0                9
#
#    KM/engine size  Price/Doors  Wheels  Pass road safety
# 0     1000.000000  1000.000000       4              True
# 1     1250.000000  1250.000000       4              True
# ...

# %%
car_sales=car_sales.drop('KM/engine size',axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 0  Toyota  White         150043      4   4000.0    5.0                5
# 1   Honda    Red          87899      4   5000.0    5.0                3
# 2  Toyota   Blue          32549      3   7000.0    5.0                9
# 3     BMW  Black          11179      5  22000.0    5.0               54
# 4  Nissan  White         213095      4   3500.0    5.0                2
# 5  Toyota  Green          99213      4   4500.0    5.0                5
# 6   Honda   Blue          45698      4   7500.0    5.0                5
# 7   Honda   Blue          54738      4   7000.0    5.0                1
# 8  Toyota  White          60000      4   6250.0    5.0                2
# 9  Nissan  White          31600      4   9700.0    5.0                9
#
#    Price/Doors  Wheels  Pass road safety
# 0  1000.000000       4              True
# 1  1250.000000       4              True
# 2  2333.333333       4              True
# ...

# %%
car_sales_sample=car_sales.sample(frac=1)

# %%
car_sales_sample
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 9  Nissan  White          31600      4   9700.0    5.0                9
# 4  Nissan  White         213095      4   3500.0    5.0                2
# 5  Toyota  Green          99213      4   4500.0    5.0                5
# 8  Toyota  White          60000      4   6250.0    5.0                2
# 0  Toyota  White         150043      4   4000.0    5.0                5
# 1   Honda    Red          87899      4   5000.0    5.0                3
# 6   Honda   Blue          45698      4   7500.0    5.0                5
# 2  Toyota   Blue          32549      3   7000.0    5.0                9
# 3     BMW  Black          11179      5  22000.0    5.0               54
# 7   Honda   Blue          54738      4   7000.0    5.0                1
#
#    Price/Doors  Wheels  Pass road safety
# 9  2425.000000       4              True
# 4   875.000000       4              True
# 5  1125.000000       4              True
# ...

# %%
car_sales_sample.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0      9  Nissan  White          31600      4   9700.0    5.0
# 1      4  Nissan  White         213095      4   3500.0    5.0
# 2      5  Toyota  Green          99213      4   4500.0    5.0
# 3      8  Toyota  White          60000      4   6250.0    5.0
# 4      0  Toyota  White         150043      4   4000.0    5.0
# 5      1   Honda    Red          87899      4   5000.0    5.0
# 6      6   Honda   Blue          45698      4   7500.0    5.0
# 7      2  Toyota   Blue          32549      3   7000.0    5.0
# 8      3     BMW  Black          11179      5  22000.0    5.0
# 9      7   Honda   Blue          54738      4   7000.0    5.0
#
#    engine size (L)  Price/Doors  Wheels  Pass road safety
# 0                9  2425.000000       4              True
# 1                2   875.000000       4              True
# 2                5  1125.000000       4              True
# ...

# %%
#Change the odometer value from KM to miles
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 0  Toyota  White         150043      4   4000.0    5.0                5
# 1   Honda    Red          87899      4   5000.0    5.0                3
# 2  Toyota   Blue          32549      3   7000.0    5.0                9
# 3     BMW  Black          11179      5  22000.0    5.0               54
# 4  Nissan  White         213095      4   3500.0    5.0                2
# 5  Toyota  Green          99213      4   4500.0    5.0                5
# 6   Honda   Blue          45698      4   7500.0    5.0                5
# 7   Honda   Blue          54738      4   7000.0    5.0                1
# 8  Toyota  White          60000      4   6250.0    5.0                2
# 9  Nissan  White          31600      4   9700.0    5.0                9
#
#    Price/Doors  Wheels  Pass road safety
# 0  1000.000000       4              True
# 1  1250.000000       4              True
# 2  2333.333333       4              True
# ...

# %%
car_sales['Odometer (KM)']=car_sales['Odometer (KM)'].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 0  Toyota  White      93776.875      4   4000.0    5.0                5
# 1   Honda    Red      54936.875      4   5000.0    5.0                3
# 2  Toyota   Blue      20343.125      3   7000.0    5.0                9
# 3     BMW  Black       6986.875      5  22000.0    5.0               54
# 4  Nissan  White     133184.375      4   3500.0    5.0                2
# 5  Toyota  Green      62008.125      4   4500.0    5.0                5
# 6   Honda   Blue      28561.250      4   7500.0    5.0                5
# 7   Honda   Blue      34211.250      4   7000.0    5.0                1
# 8  Toyota  White      37500.000      4   6250.0    5.0                2
# 9  Nissan  White      19750.000      4   9700.0    5.0                9
#
#    Price/Doors  Wheels  Pass road safety
# 0  1000.000000       4              True
# 1  1250.000000       4              True
# 2  2333.333333       4              True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 0  Toyota  White      93776.875      4   4000.0    5.0                5
# 1   Honda    Red      54936.875      4   5000.0    5.0                3
# 2  Toyota   Blue      20343.125      3   7000.0    5.0                9
# 3     BMW  Black       6986.875      5  22000.0    5.0               54
# 4  Nissan  White     133184.375      4   3500.0    5.0                2
# 5  Toyota  Green      62008.125      4   4500.0    5.0                5
# 6   Honda   Blue      28561.250      4   7500.0    5.0                5
# 7   Honda   Blue      34211.250      4   7000.0    5.0                1
# 8  Toyota  White      37500.000      4   6250.0    5.0                2
# 9  Nissan  White      19750.000      4   9700.0    5.0                9
#
#    Price/Doors  Wheels  Pass road safety
# 0  1000.000000       4              True
# 1  1250.000000       4              True
# 2  2333.333333       4              True
# ...

# %%
car_sales['Wheels']=3

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 0  Toyota  White      93776.875      4   4000.0    5.0                5
# 1   Honda    Red      54936.875      4   5000.0    5.0                3
# 2  Toyota   Blue      20343.125      3   7000.0    5.0                9
# 3     BMW  Black       6986.875      5  22000.0    5.0               54
# 4  Nissan  White     133184.375      4   3500.0    5.0                2
# 5  Toyota  Green      62008.125      4   4500.0    5.0                5
# 6   Honda   Blue      28561.250      4   7500.0    5.0                5
# 7   Honda   Blue      34211.250      4   7000.0    5.0                1
# 8  Toyota  White      37500.000      4   6250.0    5.0                2
# 9  Nissan  White      19750.000      4   9700.0    5.0                9
#
#    Price/Doors  Wheels  Pass road safety
# 0  1000.000000       3              True
# 1  1250.000000       3              True
# 2  2333.333333       3              True
# ...

# %%
car_sales['Doors']=car_sales['Doors'].apply(lambda x: x**2)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  engine size (L)  \
# 0  Toyota  White      93776.875     16   4000.0    5.0                5
# 1   Honda    Red      54936.875     16   5000.0    5.0                3
# 2  Toyota   Blue      20343.125      9   7000.0    5.0                9
# 3     BMW  Black       6986.875     25  22000.0    5.0               54
# 4  Nissan  White     133184.375     16   3500.0    5.0                2
# 5  Toyota  Green      62008.125     16   4500.0    5.0                5
# 6   Honda   Blue      28561.250     16   7500.0    5.0                5
# 7   Honda   Blue      34211.250     16   7000.0    5.0                1
# 8  Toyota  White      37500.000     16   6250.0    5.0                2
# 9  Nissan  White      19750.000     16   9700.0    5.0                9
#
#    Price/Doors  Wheels  Pass road safety
# 0  1000.000000       3              True
# 1  1250.000000       3              True
# 2  2333.333333       3              True
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-268-4c89b84d18a7> in <module>
# ----> 1 car_sales[loc]=3
#
# NameError: name 'loc' is not defined

# %%
company
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Make, dtype: bool

# %%
all_india['pincode'].sum()
# Out:
# 77632172711
